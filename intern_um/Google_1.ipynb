# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 import numpy as np
#       3 from tensorflow import keras
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\tensorflow\__init__.py:464
#     462     importlib.import_module("tf_keras.src.optimizers")
#     463   else:
# --> 464     importlib.import_module("keras.src.optimizers")
#     465 except (ImportError, AttributeError):
#     466   pass
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\importlib\__init__.py:126, in import_module(name, package)
#     124             break
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# ...
